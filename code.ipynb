# %% [markdown]
# #Volume de tráfego médio mensal que passam nos equipamentos de Fiscalização Eletrônica de Fortaleza.

# %% [markdown]
# ###Dicionário de variáveis
#
#
# *   SITIO:
# *   LONG: Longitude.
# *   LAT: Latitude.
# *   VIA_SENTIDO: Sentido da via.
# *   DATA: Data em que os dados foram registrados. (2017 - 2022)
# *   VMD: O *Volume Médio Diário* (VMD) é o volume ou tráfego registrado em um dia (24 horas). Esse dado é utilizado para avaliar a distribuição de tráfego, medir a demanda de uma via e programar melhorias básicas.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn import preprocessing

# %%
'''
Caso queira usar pelo Google Colab ajuda usar o Drive
from google.colab import drive
drive.mount('/content/drive')
'''
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'''
#Primerio dado
df = pd.read_csv("localização dele no seu Drive")
df
'''
# Out:
#        Unnamed: 0     SITIO       LONG       LAT  \
# 0               1  01385016 -38.572696 -3.712192
# 1               2  01385017 -38.572683 -3.712145
# 2               3  01385028 -38.615730 -3.818608
# 3               4  01385029 -38.615600 -3.818744
# 4               5  01385030 -38.574740 -3.811549
# ...           ...       ...        ...       ...
# 20505       20506     FS142 -38.532926 -3.795249
# 20506       20507     FS144 -38.560709 -3.819893
# 20507       20508     FS145 -38.562657 -3.819108
# 20508       20509     FS146 -38.573170 -3.806822
# 20509       20510     FS147 -38.510391 -3.769414
#
#                           VIA_SENTIDO     DATA    VMD
# 0              AV. FRANCISCO SA [O-L]  2017-01   8765
# 1              AV. FRANCISCO SA [L-O]  2017-01   9357
# 2      AV. GEN. OSORIO DE PAIVA [N-S]  2017-01  16558
# 3      AV. GEN. OSORIO DE PAIVA [S-N]  2017-01  15843
# 4          AV. GODOFREDO MACIEL [N-S]  2017-01  19433
# ...                               ...      ...    ...
# 20505     AV. DR. SILAS MUNGUBA [O-L]  2022-12  10177
# 20506   AV. PRES. COSTA E SILVA [L-O]  2022-12  10322
# 20507   AV. PRES. COSTA E SILVA [O-L]  2022-12  11773
# 20508      AV. GODOFREDO MACIEL [N-S]  2022-12  11045
# 20509     AV. GOV. RAUL BARBOSA [N-S]  2022-12  22550
#
# [20510 rows x 7 columns]

# %%
#Primerio dado
df = pd.read_csv("volumetrafegomensal-1.csv")
df

# %%
#Separa o ano e data em duas novas colunas, e tira a coluna Unnamed: 0.
df["DATA"] = pd.to_datetime(df["DATA"])
df['ANO'] = df['DATA'].dt.year
df['MES'] = df['DATA'].dt.month
df = df.drop(columns=["DATA"] )
df = df.drop(columns=["Unnamed: 0"])
df
# Out:
#           SITIO       LONG       LAT                     VIA_SENTIDO    VMD  \
# 0      01385016 -38.572696 -3.712192          AV. FRANCISCO SA [O-L]   8765
# 1      01385017 -38.572683 -3.712145          AV. FRANCISCO SA [L-O]   9357
# 2      01385028 -38.615730 -3.818608  AV. GEN. OSORIO DE PAIVA [N-S]  16558
# 3      01385029 -38.615600 -3.818744  AV. GEN. OSORIO DE PAIVA [S-N]  15843
# 4      01385030 -38.574740 -3.811549      AV. GODOFREDO MACIEL [N-S]  19433
# ...         ...        ...       ...                             ...    ...
# 20505     FS142 -38.532926 -3.795249     AV. DR. SILAS MUNGUBA [O-L]  10177
# 20506     FS144 -38.560709 -3.819893   AV. PRES. COSTA E SILVA [L-O]  10322
# 20507     FS145 -38.562657 -3.819108   AV. PRES. COSTA E SILVA [O-L]  11773
# 20508     FS146 -38.573170 -3.806822      AV. GODOFREDO MACIEL [N-S]  11045
# 20509     FS147 -38.510391 -3.769414     AV. GOV. RAUL BARBOSA [N-S]  22550
#
#         ANO  MES
# 0      2017    1
# 1      2017    1
# 2      2017    1
# 3      2017    1
# 4      2017    1
# ...     ...  ...
# 20505  2022   12
# 20506  2022   12
# 20507  2022   12
# 20508  2022   12
# 20509  2022   12
#
# [20510 rows x 7 columns]

# %%
df.shape
# Out:
# (20510, 7)

# %%
df.dtypes
# Out:
# SITIO           object
# LONG           float64
# LAT            float64
# VIA_SENTIDO     object
# VMD              int64
# ANO              int64
# MES              int64
# dtype: object

# %%
df.isnull().sum()
#nenhum dado nulo
# Out:
# SITIO          0
# LONG           0
# LAT            0
# VIA_SENTIDO    0
# VMD            0
# ANO            0
# MES            0
# dtype: int64

# %%
df.sample(5)
# Out:
#           SITIO       LONG       LAT                         VIA_SENTIDO  \
# 1008   01385074 -38.569601 -3.707902      AV. PRES. CASTELO BRANCO [L-O]
# 1130   01385289 -38.512265 -3.742433             AV. ANTONIO SALES [O-L]
# 95     01385211 -38.571975 -3.803436          AV. GODOFREDO MACIEL [S-N]
# 12835  01385220 -38.506370 -3.726773  R. DEPUTADO MOREIRA DA ROCHA [L-O]
# 8222      AT235 -38.581439 -3.702860      AV. PRES. CASTELO BRANCO [L-O]
#
#          VMD   ANO  MES
# 1008   23693  2017    4
# 1130    4161  2017    4
# 95     22023  2017    1
# 12835   7463  2020    6
# 8222   15063  2019    3

# %% [markdown]
# ##Modelando

# %%
X = df.drop(columns=["SITIO","VIA_SENTIDO","VMD"] )
y = df["VMD"]
X
# Out:
#             LONG       LAT   ANO  MES
# 0     -38.572696 -3.712192  2017    1
# 1     -38.572683 -3.712145  2017    1
# 2     -38.615730 -3.818608  2017    1
# 3     -38.615600 -3.818744  2017    1
# 4     -38.574740 -3.811549  2017    1
# ...          ...       ...   ...  ...
# 20505 -38.532926 -3.795249  2022   12
# 20506 -38.560709 -3.819893  2022   12
# 20507 -38.562657 -3.819108  2022   12
# 20508 -38.573170 -3.806822  2022   12
# 20509 -38.510391 -3.769414  2022   12
#
# [20510 rows x 4 columns]

# %%
#treinando o algoritimo
X_train, X_test , y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=42 )

# %%
X_train.shape, X_test.shape
# Out:
# ((14357, 4), (6153, 4))

# %%
y_train.shape, y_test.shape
# Out:
# ((14357,), (6153,))

# %%
X_train
# Out:
#             LONG       LAT   ANO  MES
# 18011 -38.518690 -3.740422  2022    1
# 5267  -38.493031 -3.738022  2018    6
# 14460 -38.555480 -3.755081  2020   11
# 15232 -38.517680 -3.740739  2021    1
# 1246  -38.508263 -3.806640  2017    4
# ...          ...       ...   ...  ...
# 11284 -38.532240 -3.719128  2020    1
# 11964 -38.496091 -3.747451  2020    3
# 5390  -38.585192 -3.741946  2018    6
# 860   -38.509774 -3.721552  2017    3
# 15795 -38.499037 -3.746531  2021    3
#
# [14357 rows x 4 columns]

# %%
y_train
# Out:
# 18011     1361
# 5267      1950
# 14460     8835
# 15232     1491
# 1246     22798
#          ...
# 11284    28115
# 11964     1502
# 5390     14376
# 860       9555
# 15795      804
# Name: VMD, Length: 14357, dtype: int64

# %%
def RegressionModel(model,X_test, y_test):
  pred = model.predict(X_test)
  print("R2 Score: ", r2_score(y_test, pred))
  print("Mean Absolute Error (MAE): ", mean_absolute_error(y_test,pred))

# %% [markdown]
# ##Classificando

# %%
#DecisionTree
dt = DecisionTreeRegressor(random_state=42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
dt_pred = dt.predict(X_test)

# %%
RegressionModel(dt,X_test, y_test)
# Out:
# R2 Score:  0.9331890811577446
# Mean Absolute Error (MAE):  1064.3356086461888

# %%
fig = px.scatter(x=y_test, y=dt_pred, title="Real x Previsto", trendline="ols", labels={"x":"Real","y":"Previsto"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4b0373ef-0fa8-42cb-8cd9-58bbd2935abe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b0373ef-0fa8-42cb-8cd9-58bbd2935abe")) {                    Plotly.newPlot(                        "4b0373ef-0fa8-42cb-8cd9-58bbd2935abe",                        [{"hovertemplate":"Real=%{x}<br>Previsto=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[178,7266,17626,19858,9431,9550,992,17884,1006,12885,20019,10205,22709,3863,13094,8555,7569,21498,5592,383,934,5968,11405,17429,1903,22782,281,10803,2219,36532,14993,307,330,6934,23264,5183,1038,11996,15862,13632,10908,10902,3291,12792,20153,4502,4177,1955,7053,2662,11944,23802,1214,7013,14354,2074,1355,37647,6526,14277,33959,1973,2736,18302,7529,15630,17381,8294,216,10946,7142,24103,15286,356,1563,2281,16737,4319,14453,14273,5372,14735,7527,19579,8589,8646,14569,5798,11194,2527,1656,1870,24528,1374,2648,8689,20873,15395,12011,1138,745,6696,292,15217,2207,20217,1506,2435,5990,8468,20753,2619,21634,8751,16059,2717,25382,2824,1210,25702,1013,23101,256,1240,8321,1366,10603,737,2284,20300,14546,2071,12837,14659,12990,2450,4575,2780,8757,2715,9743,18256,5612,20607,719,29279,603,20293,406,114,37895,21010,1893,6498,614,771,4350,1093,16851,10660,10267,10293,22047,5037,17116,536,13613,23230,23070,15274,1785,17972,7818,4589,2294,1879,15948,22674,8366,1296,19517,2554,2648,467,1577,685,1666,22356,23475,31426,642,2774,12116,19430,20667,12412,50,2209,12385,14000,20774,8718,16444,2392,632,1235,21928,623,18302,7786,18676,25742,35509,11720,11013,15234,18540,1888,17935,2314,9813,16278,10536,8176,12947,22970,20492,21177,14263,11688,2798,19521,8231,1790,2395,16912,7618,23825,16561,2125,1065,5262,3184,23005,11604,8,15033,23320,16994,2711,11354,11256,9247,4820,6613,4576,8234,13439,2960,7687,6234,17057,23196,8096,15394,1817,13984,1823,28677,18747,15302,17757,17941,1958,1519,4,13293,13416,14621,8186,425,14572,533,18